# %% [markdown]
# # Pairs Trading Research
#
# Cointegration scan and spread diagnostics.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from quant_research_lab.data.market_data import download_prices
from quant_research_lab.strategies.pairs_trading import find_cointegrated_pairs
prices = download_prices(['MSFT', 'AAPL', 'GOOGL', 'META'], '2020-01-01')
find_cointegrated_pairs(prices).head()
