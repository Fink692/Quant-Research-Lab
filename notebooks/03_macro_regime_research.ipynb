# %% [markdown]
# # Macro Regime Research
#
# Feature engineering, PCA, and clustering workflow.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from quant_research_lab.data.fred_data import generate_synthetic_macro
from quant_research_lab.macro.macro_features import build_macro_features, standardize_features
from quant_research_lab.macro.regime_detection import detect_regimes
features = build_macro_features(generate_synthetic_macro())
regimes, pca, model = detect_regimes(standardize_features(features))
regimes.tail()
