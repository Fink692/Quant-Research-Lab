# %% [markdown]
# # Volatility Surface Research
#
# Options-chain cleaning, implied volatility, Greeks, and surface interpolation.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from quant_research_lab.data.options_data import generate_synthetic_options_chain
from quant_research_lab.derivatives.volatility_surface import clean_options_chain, enrich_options_chain
raw = generate_synthetic_options_chain(spot=500)
clean = clean_options_chain(raw)
enriched = enrich_options_chain(clean, spot=500, risk_free_rate=0.04, dividend_yield=0.015)
enriched[['expiration', 'option_type', 'strike', 'implied_volatility', 'delta', 'gamma']].head()
