# %% [markdown]
# # Risk Dashboard Research
#
# This notebook demonstrates the reusable portfolio risk modules. Run the CLI script for full saved outputs.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from quant_research_lab.data.market_data import download_prices, calculate_returns
from quant_research_lab.risk.portfolio_metrics import performance_summary, portfolio_returns
prices = download_prices(['SPY', 'IEF', 'GLD'], '2020-01-01')
returns = calculate_returns(prices)
portfolio = portfolio_returns(returns, {'SPY': 0.6, 'IEF': 0.25, 'GLD': 0.15})
performance_summary(portfolio, returns['SPY'])
