# %% [markdown]
# # Backtesting Research
#
# Minimal example using the institutional backtesting engine.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from quant_research_lab.data.market_data import download_prices
from quant_research_lab.backtesting.engine import BacktestEngine
from quant_research_lab.strategies.momentum import buy_and_hold_weights
prices = download_prices(['SPY'], '2020-01-01')
weights = buy_and_hold_weights(prices, 'SPY')
result = BacktestEngine(prices).run('buy_hold', weights)
result.metrics
